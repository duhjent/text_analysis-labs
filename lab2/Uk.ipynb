# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn import mixture
import nltk
from nltk.tokenize import word_tokenize
from uk_stemmer import UkStemmer
from string import punctuation
from typing import List
from sklearn.feature_extraction.text import TfidfVectorizer
import re
from sklearn.model_selection import train_test_split
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# # Helper functions

# %%
stemmer = UkStemmer()

incorrect_stopwords = ['рос']

with open('./data/stopwords_ua.txt') as f_stopwords:
    stopwords = [x.replace('\n', '') for x in f_stopwords.readlines()]
    stopwords = [sw for sw in stopwords if sw not in incorrect_stopwords]

num_re = re.compile(r'\d+')
words_re = re.compile(r'\w+')

def prepare_uk(text: str) -> List[str]:
    tokens = word_tokenize(text.lower())
    tokens = [stemmer.stem_word(t) for t in tokens]
    tokens = [t for t in tokens if t not in punctuation]
    tokens = [t for t in tokens if t not in stopwords]
    tokens = [t for t in tokens if num_re.match(t) is None]
    tokens = [t for t in tokens if words_re.match(t) is not None]

    return ' '.join(tokens)

# %% [markdown]
# # Data import

# %% [markdown]
# ## Read

# %%
df = pd.read_csv('./data/data_set_4.csv.zip')

df = df.drop(columns=['Unnamed: 0'])

df
# Out:
#                                 Link  \
# 0      https://t.me/c/1376264484/328
# 1      https://t.me/c/1376264484/338
# 2      https://t.me/c/1376264484/350
# 3      https://t.me/c/1376264484/361
# 4      https://t.me/c/1376264484/366
# ...                              ...
# 10730     https://t.me/warfakes/8878
# 10731     https://t.me/warfakes/8903
# 10732     https://t.me/warfakes/8907
# 10733     https://t.me/warfakes/8909
# 10734     https://t.me/warfakes/8913
#
#                                                     Text  Label
# 0      Просто слухайте цей діалог. Ні, це не нарізка ...   True
# 1      ️ Рубль став найнестабільнішою валютою у всьом...   True
# 2      Перше звернення мера Мелітополя Івана Федорова...   True
# 3      Росія загрожує Боснії "українським сценарієм" ...   True
# 4      Енергоатом повідомив, що окупанти пошкодили ви...   True
# ...                                                  ...    ...
# 10730  Громадян Таджикистану, який убив 11 людей на п...  False
# 10731  : Російська туристична компанія помилково відп...  False
# 10732  Відеозвернення губернатора Херсонської області...  False
# 10733  Росіяни на Новий рік залишаться без текіли, бу...  False
# 10734  : Французький розробник та видавець відеоігор ...  False
#
# [10735 rows x 3 columns]

# %% [markdown]
# ## Preprocess text

# %%
df['text_preprocessed'] = df['Text'].apply(prepare_uk)

df
# Out:
#                                 Link  \
# 0      https://t.me/c/1376264484/328
# 1      https://t.me/c/1376264484/338
# 2      https://t.me/c/1376264484/350
# 3      https://t.me/c/1376264484/361
# 4      https://t.me/c/1376264484/366
# ...                              ...
# 10730     https://t.me/warfakes/8878
# 10731     https://t.me/warfakes/8903
# 10732     https://t.me/warfakes/8907
# 10733     https://t.me/warfakes/8909
# 10734     https://t.me/warfakes/8913
#
#                                                     Text  Label  \
# 0      Просто слухайте цей діалог. Ні, це не нарізка ...   True
# 1      ️ Рубль став найнестабільнішою валютою у всьом...   True
# 2      Перше звернення мера Мелітополя Івана Федорова...   True
# 3      Росія загрожує Боснії "українським сценарієм" ...   True
# 4      Енергоатом повідомив, що окупанти пошкодили ви...   True
# ...                                                  ...    ...
# 10730  Громадян Таджикистану, який убив 11 людей на п...  False
# 10731  : Російська туристична компанія помилково відп...  False
# 10732  Відеозвернення губернатора Херсонської області...  False
# 10733  Росіяни на Новий рік залишаться без текіли, бу...  False
# 10734  : Французький розробник та видавець відеоігор ...  False
#
#                                        text_preprocessed
# 0             прост слухайт діалог нарізк фільм тарантін
# 1                  рубл найнестабільніш валют всьом світ
# 2      перш зверненн мер мелітопол іван федор післ зв...
# 3      рос загрож босні українськ сценарі можлив всту...
# 4      енергоат повідом окупант пошкодил високовольтн...
# ...                                                  ...
# 10730  громадян таджикистан уб люд полігон білгород п...
# 10731  російськ туристичн компан помилков відправля б...
# 10732  відеозверненн губернатор херсонськ област воло...
# 10733  росіян нов залиш текіл бурбон коньяк французьк...
# 10734  французьк розробник видавец відеоігор ubisoft ...
#
# [10735 rows x 4 columns]

# %% [markdown]
# ## Save preprocessed

# %%
df.to_csv('./data/preprocessed_uk.csv', index=False)

# %% [markdown]
# ## Load preprocessed

# %%
df = pd.read_csv('./data/preprocessed_uk.csv')

df
# Out:
#                                 Link  \
# 0      https://t.me/c/1376264484/328
# 1      https://t.me/c/1376264484/338
# 2      https://t.me/c/1376264484/350
# 3      https://t.me/c/1376264484/361
# 4      https://t.me/c/1376264484/366
# ...                              ...
# 10730     https://t.me/warfakes/8878
# 10731     https://t.me/warfakes/8903
# 10732     https://t.me/warfakes/8907
# 10733     https://t.me/warfakes/8909
# 10734     https://t.me/warfakes/8913
#
#                                                     Text  Label  \
# 0      Просто слухайте цей діалог. Ні, це не нарізка ...   True
# 1      ️ Рубль став найнестабільнішою валютою у всьом...   True
# 2      Перше звернення мера Мелітополя Івана Федорова...   True
# 3      Росія загрожує Боснії "українським сценарієм" ...   True
# 4      Енергоатом повідомив, що окупанти пошкодили ви...   True
# ...                                                  ...    ...
# 10730  Громадян Таджикистану, який убив 11 людей на п...  False
# 10731  : Російська туристична компанія помилково відп...  False
# 10732  Відеозвернення губернатора Херсонської області...  False
# 10733  Росіяни на Новий рік залишаться без текіли, бу...  False
# 10734  : Французький розробник та видавець відеоігор ...  False
#
#                                        text_preprocessed
# 0             прост слухайт діалог нарізк фільм тарантін
# 1                  рубл найнестабільніш валют всьом світ
# 2      перш зверненн мер мелітопол іван федор післ зв...
# 3      рос загрож босні українськ сценарі можлив всту...
# 4      енергоат повідом окупант пошкодил високовольтн...
# ...                                                  ...
# 10730  громадян таджикистан уб люд полігон білгород п...
# 10731  російськ туристичн компан помилков відправля б...
# 10732  відеозверненн губернатор херсонськ област воло...
# 10733  росіян нов залиш текіл бурбон коньяк французьк...
# 10734  французьк розробник видавец відеоігор ubisoft ...
#
# [10735 rows x 4 columns]

# %% [markdown]
# ## Vectorize

# %%
vectorizer = TfidfVectorizer(tokenizer=word_tokenize, min_df=.001)

vectorized = vectorizer.fit_transform(df['text_preprocessed']).toarray()

vectorizer.get_feature_names_out()
# Out:
# /mnt/e/university/master/text_analysis-labs/venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# array(['anonymous', 'bayraktar', 'bloomberg', ..., 'італ', 'їж', 'їхн'],
#       dtype=object)

# %%
vectorizer.get_feature_names_out().shape
# Out:
# (1744,)

# %% [markdown]
# # Clustering

# %% [markdown]
# ## GMM

# %%
true_fake_model = mixture.GaussianMixture(2)

true_fake_model.fit(vectorized)
# Out:
# GaussianMixture(n_components=2)

# %% [markdown]
# ### Save model

# %%
gmm_name = './models/gmm_uk'
np.save(gmm_name + '_weights', true_fake_model.weights_, allow_pickle=False)
np.save(gmm_name + '_means', true_fake_model.means_, allow_pickle=False)
np.save(gmm_name + '_covariances', true_fake_model.covariances_, allow_pickle=False)

# %% [markdown]
# ### Load the model

# %%
means = np.load('./models/gmm_uk' + '_means.npy')
covar = np.load('./models/gmm_uk' + '_covariances.npy')
true_fake_model = mixture.GaussianMixture(n_components = len(means), covariance_type='full')
true_fake_model.precisions_cholesky_ = np.linalg.cholesky(np.linalg.inv(covar))
true_fake_model.weights_ = np.load('./models/gmm_uk' + '_weights.npy')
true_fake_model.means_ = means
true_fake_model.covariances_ = covar

# %% [markdown]
# ### Predict and add col

# %%
gmm_out = true_fake_model.predict(vectorized)

df['gmm_out'] = gmm_out
df['gmm_out'] = df['gmm_out'].astype(bool)

df
# Out:
#                                 Link  \
# 0      https://t.me/c/1376264484/328
# 1      https://t.me/c/1376264484/338
# 2      https://t.me/c/1376264484/350
# 3      https://t.me/c/1376264484/361
# 4      https://t.me/c/1376264484/366
# ...                              ...
# 10730     https://t.me/warfakes/8878
# 10731     https://t.me/warfakes/8903
# 10732     https://t.me/warfakes/8907
# 10733     https://t.me/warfakes/8909
# 10734     https://t.me/warfakes/8913
#
#                                                     Text  Label  \
# 0      Просто слухайте цей діалог. Ні, це не нарізка ...   True
# 1      ️ Рубль став найнестабільнішою валютою у всьом...   True
# 2      Перше звернення мера Мелітополя Івана Федорова...   True
# 3      Росія загрожує Боснії "українським сценарієм" ...   True
# 4      Енергоатом повідомив, що окупанти пошкодили ви...   True
# ...                                                  ...    ...
# 10730  Громадян Таджикистану, який убив 11 людей на п...  False
# 10731  : Російська туристична компанія помилково відп...  False
# 10732  Відеозвернення губернатора Херсонської області...  False
# 10733  Росіяни на Новий рік залишаться без текіли, бу...  False
# 10734  : Французький розробник та видавець відеоігор ...  False
#
#                                        text_preprocessed  gmm_out
# 0             прост слухайт діалог нарізк фільм тарантін    False
# 1                  рубл найнестабільніш валют всьом світ     True
# 2      перш зверненн мер мелітопол іван федор післ зв...     True
# 3      рос загрож босні українськ сценарі можлив всту...    False
# 4      енергоат повідом окупант пошкодил високовольтн...     True
# ...                                                  ...      ...
# 10730  громадян таджикистан уб люд полігон білгород п...     True
# 10731  російськ туристичн компан помилков відправля б...     True
# 10732  відеозверненн губернатор херсонськ област воло...     True
# 10733  росіян нов залиш текіл бурбон коньяк французьк...     True
# 10734  французьк розробник видавец відеоігор ubisoft ...    False
#
# [10735 rows x 5 columns]

# %%
len(df[df['Label'] == df['gmm_out']]) / len(df)
# Out:
# 0.4418258034466698

# %% [markdown]
# ## K-means

# %%
true_false_model_km = sklearn.cluster.KMeans(n_clusters = 2, init = 'k-means++')
kmeans_out = true_false_model_km.fit_predict(vectorized)

# %%
kmeans_out
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int32)

# %%
df['km_out'] = kmeans_out
df['km_out'] = df['km_out'].astype(bool)

df
# Out:
#                                 Link  \
# 0      https://t.me/c/1376264484/328
# 1      https://t.me/c/1376264484/338
# 2      https://t.me/c/1376264484/350
# 3      https://t.me/c/1376264484/361
# 4      https://t.me/c/1376264484/366
# ...                              ...
# 10730     https://t.me/warfakes/8878
# 10731     https://t.me/warfakes/8903
# 10732     https://t.me/warfakes/8907
# 10733     https://t.me/warfakes/8909
# 10734     https://t.me/warfakes/8913
#
#                                                     Text  Label  \
# 0      Просто слухайте цей діалог. Ні, це не нарізка ...   True
# 1      ️ Рубль став найнестабільнішою валютою у всьом...   True
# 2      Перше звернення мера Мелітополя Івана Федорова...   True
# 3      Росія загрожує Боснії "українським сценарієм" ...   True
# 4      Енергоатом повідомив, що окупанти пошкодили ви...   True
# ...                                                  ...    ...
# 10730  Громадян Таджикистану, який убив 11 людей на п...  False
# 10731  : Російська туристична компанія помилково відп...  False
# 10732  Відеозвернення губернатора Херсонської області...  False
# 10733  Росіяни на Новий рік залишаться без текіли, бу...  False
# 10734  : Французький розробник та видавець відеоігор ...  False
#
#                                        text_preprocessed  gmm_out  km_out
# 0             прост слухайт діалог нарізк фільм тарантін    False   False
# 1                  рубл найнестабільніш валют всьом світ     True   False
# 2      перш зверненн мер мелітопол іван федор післ зв...     True   False
# 3      рос загрож босні українськ сценарі можлив всту...    False   False
# 4      енергоат повідом окупант пошкодил високовольтн...     True   False
# ...                                                  ...      ...     ...
# 10730  громадян таджикистан уб люд полігон білгород п...     True   False
# 10731  російськ туристичн компан помилков відправля б...     True   False
# 10732  відеозверненн губернатор херсонськ област воло...     True   False
# 10733  росіян нов залиш текіл бурбон коньяк французьк...     True   False
# 10734  французьк розробник видавец відеоігор ubisoft ...    False   False
#
# [10735 rows x 6 columns]

# %%
len(df[df['Label'] == df['km_out']]) / len(df)
# Out:
# 0.47498835584536564

# %% [markdown]
# # Classification

# %% [markdown]
# ## Train-test-split etc

# %%
df_train, df_test = train_test_split(df, train_size=.7, shuffle=True, random_state=42)

len(df_train), len(df_test)
# Out:
# (7514, 3221)

# %%
vectorizer_classification = TfidfVectorizer(tokenizer=word_tokenize, min_df=.001)

X_train = vectorizer_classification.fit_transform(df_train['text_preprocessed'])
y_train = df_train['Label'].to_numpy(dtype=float)

X_test = vectorizer_classification.transform(df_test['text_preprocessed'])
y_test = df_test['Label'].to_numpy(dtype=float)
# Out:
# /mnt/e/university/master/text_analysis-labs/venv/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %% [markdown]
# ## Logistic regression

# %%
lr_model = sklearn.linear_model.LogisticRegression(solver='liblinear')
lr_model.fit(X_train, y_train)
lr_pred =  lr_model.predict(X_test)

# %%
sklearn.metrics.accuracy_score(y_test, lr_pred)
# Out:
# 0.8810928283141881

# %% [markdown]
# ## SVM

# %% [markdown]
# ### Default kernel

# %%
svm_model1 = sklearn.svm.SVC()
svm_model1.fit(X_train, y_train)
svm1_pred = svm_model1.predict(X_test)

sklearn.metrics.accuracy_score(y_test, svm1_pred)
# Out:
# 0.889164855634896

# %% [markdown]
# ### Linear

# %%
svm_model2 = sklearn.svm.SVC(kernel='linear')
svm_model2.fit(X_train, y_train)
svm2_pred = svm_model1.predict(X_test)

sklearn.metrics.accuracy_score(y_test, svm2_pred)
# Out:
# 0.889164855634896

# %% [markdown]
# ### Degree

# %%
svm_model3 = sklearn.svm.SVC(kernel='poly')
svm_model3.fit(X_train, y_train)
svm3_pred = svm_model3.predict(X_test)

sklearn.metrics.accuracy_score(y_test, svm3_pred)
# Out:
# 0.8134119838559454
