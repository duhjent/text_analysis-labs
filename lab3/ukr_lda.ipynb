# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from nltk.tokenize import word_tokenize

# %%
nrows = 10000

df = pd.read_csv('./data/uk-cut-processed.csv', nrows=nrows)

df
# Out:
#                                                headline  \
# 0     Збитки на понад 9 мільйонів євро: у Дніпрі пій...
# 1                                      Друзі при Балтії
# 2     Обласна влада привітала жінок концертом Зібров...
# 3     Кличко доручив створити робочу групу і навести...
# 4             Вчені прирівняли переїдання до наркоманії
# ...                                                 ...
# 9995                                              Відео
# 9996  В Україні лише за рік вдвічі поменшало волонтерів
# 9997  На Гонконг насувається тайфун "Ханун", оголоше...
# 9998  Поляки предложили Януковичу отпустить Тимошенк...
# 9999  Сімферопольські циркачі вступили в Партію регі...
#
#                                       headline_prcessed
# 0     збитк мільйон євр дніпр пійм учасник міжнародн...
# 1                                            друз балті
# 2     обласн влад привітал жінок концерт зібр братів...
# 3     кличк доруч створит робоч груп навест лад буді...
# 4                    вчен прирівнял переїданн наркомані
# ...                                                 ...
# 9995                                               віде
# 9996                     україн вдвіч поменшал волонтер
# 9997  гонконг насуваєт тайфун ханун оголошен шторм п...
# 9998  поляк предложил янукович отпустит тимошенк леч...
# 9999          сімферопольськ циркач вступил парт регіон
#
# [10000 rows x 2 columns]

# %%
cnt_vectorizer = CountVectorizer(min_df=.002, tokenizer=word_tokenize)
X = cnt_vectorizer.fit_transform(df['headline_prcessed'])

X
# Out:
# <10000x481 sparse matrix of type '<class 'numpy.int64'>'
# 	with 23140 stored elements in Compressed Sparse Row format>

# %%
cnt_vectorizer.get_feature_names_out()
# Out:
# array(['covid-19', 'аб', 'авт', 'автобус', 'автомобіл', 'адвокат',
#        'аеропорт', 'азар', 'активіст', 'акц', 'ал', 'американськ',
#        'арешт', 'ахмет', 'банк', 'близьк', 'бойовик', 'борг', 'боротьб',
#        'брат', 'британі', 'буд', 'будинк', 'будут', 'будівництв', 'бул',
#        'бут', 'бюджет', 'бют', 'бійц', 'біл', 'білорус', 'важк', 'вакцин',
#        'валют', 'вбивств', 'вваж', 'велик', 'вересн', 'верховн', 'вибор',
#        'вибух', 'визн', 'викр', 'вимаг', 'вимагают', 'виробництв',
#        'виступ', 'виявил', 'влад', 'вод', 'вперш', 'вр', 'втрат', 'вулиц',
#        'вчен', 'відбудет', 'віде', 'відкрил', 'відкрит', 'відкритт',
#        'відмов', 'відмовил', 'відом', 'відставк', 'війн', 'військ',
#        'військов', 'газ', 'газпр', 'глав', 'гол', 'голов', 'головн',
#        'гот', 'гпу', 'гривен', 'гривн', 'грип', 'грн', 'громадян', 'грош',
#        'грудн', 'груп', 'дал', 'дан', 'дво', 'ден', 'депут', 'депутат',
#        'динам', 'директор', 'дитин', 'днр', 'дня', 'дні', 'дніпр', 'доб',
#        'дозвол', 'дозволил', 'документ', 'долар', 'донбас', 'донецьк',
#        'допомог', 'дорог', 'дощ', 'друг', 'дружин', 'дтп', 'ді', 'діт',
#        'економік', 'експерт', 'жертв', 'жител', 'житт', 'журналіст',
#        'жінк', 'заарештув', 'заборон', 'заборонил', 'завтр', 'загибл',
#        'загинув', 'загинул', 'заклик', 'закон', 'законопроект', 'закрит',
#        'залиш', 'зарпл', 'зарплат', 'заступник', 'засіданн', 'затрим',
#        'затримал', 'затриман', 'заход', 'заяв', 'заявил', 'збив', 'збро',
#        'збірн', 'звільн', 'звільнит', 'зеленськ', 'земл', 'змі', 'змін',
#        'знайшл', 'знов', 'золот', 'зон', 'зросл', 'зростанн', 'зустріч',
#        'зявил', 'из', 'йог', 'кабмін', 'кандидат', 'карантин', 'квартир',
#        'керівник', 'ки', 'кита', 'києв', 'київськ', 'кличк', 'кол',
#        'колишн', 'команд', 'компан', 'конфлікт', 'кордон', 'коронавірус',
#        'кошт', 'кращ', 'країн', 'кредит', 'кремл', 'криз', 'крим',
#        'кримськ', 'кримінальн', 'курс', 'кількіст', 'кінц', 'липн',
#        'литв', 'литвин', 'луганськ', 'луценк', 'львов', 'львівськ',
#        'львівщин', 'люд', 'людин', 'лют', 'ліг', 'лідер', 'лікар',
#        'лікарн', 'літак', 'ма', 'майдан', 'майж', 'матч', 'машин', 'мвс',
#        'мвф', 'мер', 'мереж', 'меркел', 'мзс', 'млн', 'млрд', 'можн',
#        'можут', 'моз', 'мор', 'мороз', 'москв', 'міжбанк', 'міжнародн',
#        'мільйон', 'мільярд', 'міліц', 'міноборон', 'мінськ', 'мінфін',
#        'міністр', 'міст', 'місц', 'міськ', 'міськрад', 'місяц', 'назв',
#        'назван', 'найкращ', 'намаг', 'намір', 'напад', 'нардеп', 'народ',
#        'народн', 'наступн', 'нат', 'нафт', 'нафтогаз', 'нацбанк',
#        'національн', 'нбу', 'невідом', 'незаконн', 'нем', 'нов', 'новин',
#        'німеччин', 'ніч', 'област', 'обс', 'обстріл', 'обстрілял',
#        'обшук', 'обіця', 'оголос', 'оголосил', 'одес', 'одеськ', 'одн',
#        'окупант', 'окупован', 'оон', 'опитуванн', 'опозиці', 'осіб',
#        'отрим', 'офіс', 'офіційн', 'парламент', 'парт', 'парті',
#        'переговор', 'перемог', 'перш', 'питанн', 'план', 'повернут',
#        'повідомил', 'погод', 'под', 'пожеж', 'показ', 'полон', 'польщ',
#        'політик', 'політичн', 'поліц', 'поліцейськ', 'помер', 'померл',
#        'поранен', 'порошенк', 'порушенн', 'порушил', 'посад', 'посл',
#        'постраждал', 'потрібн', 'поч', 'почал', 'початк', 'поясн', 'прав',
#        'президент', 'прем', 'премєр', 'прикордонник', 'причин', 'проблем',
#        'проведенн', 'прогноз', 'програм', 'продаж', 'продовж', 'проект',
#        'пройшл', 'прокуратур', 'пропон', 'просит', 'прот', 'протест',
#        'пункт', 'путін', 'пят', 'південн', 'північн', 'підготовк',
#        'підозр', 'підпис', 'підтрим', 'підтримк', 'післ', 'рад', 'район',
#        'ракет', 'регіон', 'реж', 'результ', 'рейтинг', 'рекордн',
#        'ремонт', 'реформ', 'ринк', 'рнбо', 'робот', 'розпов', 'розповіл',
#        'розслідуванн', 'рок', 'рос', 'росі', 'російськ', 'росіян',
#        'росіє', 'роц', 'рф', 'рівн', 'рішенн', 'саакашвіл', 'савченк',
#        'санкц', 'санкці', 'сбу', 'сво', 'свог', 'свят', 'світ', 'світов',
#        'себ', 'сил', 'син', 'сирі', 'систем', 'ситуац', 'скасув', 'склад',
#        'слуг', 'служб', 'смерт', 'сніг', 'списк', 'список', 'стал',
#        'стан', 'стат', 'створенн', 'студент', 'суд', 'судд', 'сша',
#        'сьогодн', 'січн', 'теракт', 'терорист', 'тижден', 'тижн',
#        'тимошенк', 'тис', 'травн', 'трамп', 'транспорт', 'тренер', 'трет',
#        'трьох', 'туреччин', 'турчин', 'тіл', 'угод', 'угорщин', 'удар',
#        'украин', 'україн', 'українськ', 'українц', 'укрзалізниц', 'умов',
#        'уряд', 'учасник', 'участ', 'факт', 'фестивал', 'фонд', 'франці',
#        'фільм', 'фінал', 'хабар', 'харк', 'харківськ', 'харьк', 'хвор',
#        'хмельницьк', 'хочут', 'цвк', 'центр', 'цьог', 'цін', 'частин',
#        'чек', 'чемпіон', 'чемпіонат', 'черкас', 'черкаськ', 'черніг',
#        'чернігівськ', 'чернігівщин', 'четвер', 'чиновник', 'член',
#        'чоловік', 'чорн', 'шахтар', 'школ', 'штаб', 'щод', 'ющенк', 'якщ',
#        'янукович', 'яценюк', 'євр', 'європ', 'європейськ', 'єдин', 'єс',
#        'івано-франківськ', 'ізраїл', 'інш', 'іран', 'італі'], dtype=object)

# %%
lda = LatentDirichletAllocation(n_components=10, random_state=42)
lda.fit(X)
# Out:
# LatentDirichletAllocation(random_state=42)

# %%
lda.transform(X[7])
# Out:
# array([[0.59993792, 0.10000003, 0.10000003, 0.10000003, 0.100062  ]])

# %%
n_top_words = 10
topic_words = {}
vocab = cnt_vectorizer.get_feature_names_out()

for topic, comp in enumerate(lda.components_):
    # for the n-dimensional array "arr":
    # argsort() returns a ranked n-dimensional array of arr, call it "ranked_array"
    # which contains the indices that would sort arr in a descending fashion
    # for the ith element in ranked_array, ranked_array[i] represents the index of the
    # element in arr that should be at the ith index in ranked_array
    # ex. arr = [3,7,1,0,3,6]
    # np.argsort(arr) -> [3, 2, 0, 4, 5, 1]
    # word_idx contains the indices in "topic" of the top num_top_words most relevant
    # to a given topic ... it is sorted ascending to begin with and then reversed (desc. now)    
    word_idx = np.argsort(comp)[::-1][:n_top_words]

    # store the words most relevant to the topic
    topic_words[topic] = [vocab[i] for i in word_idx]

# %%
for k, v in topic_words.items():
    print(k, v)
# Out:
# 0 ['україн', 'рос', 'єс', 'газ', 'путін', 'нат', 'цін', 'закон', 'план', 'міністр']
# 1 ['києв', 'рок', 'росі', 'ден', 'сво', 'дтп', 'поч', 'відкрил', 'протест', 'долар']
# 2 ['перш', 'област', 'російськ', 'назв', 'польщ', 'затрим', 'країн', 'друг', 'європ', 'москв']
# 3 ['змі', 'стал', 'коронавірус', 'бойовик', 'чоловік', 'загинул', 'президент', 'діт', 'украин', 'доб']
# 4 ['україн', 'українц', 'буд', 'отрим', 'щод', 'знайшл', 'прав', 'сьогодн', 'шахтар', 'оон']
# 5 ['нов', 'сша', 'рад', 'рф', 'млн', 'вибор', 'трамп', 'грн', 'україн', 'заклик']
# 6 ['тимошенк', 'янукович', 'порошенк', 'донбас', 'світ', 'військов', 'сбу', 'луценк', 'заяв', 'одн']
# 7 ['віде', 'українськ', 'ющенк', 'мзс', 'люд', 'депутат', 'под', 'йог', 'кордон', 'азар']
# 8 ['суд', 'ма', 'львівськ', 'влад', 'банк', 'робот', 'центр', 'вод', 'визн', 'курс']
# 9 ['прот', 'львов', 'крим', 'мільйон', 'післ', 'зеленськ', 'гривен', 'поліц', 'розповіл', 'біл']
